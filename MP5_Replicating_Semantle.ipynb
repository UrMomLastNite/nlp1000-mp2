# %% [markdown]
# # **Mini-project \#5**
#
# Names:
# - HERNANDEZ, RALF WADEE LACUTAB
# - TOGADO, DALRIANNE FRANCESCA B.
#
# More information on the assessment is found in our Canvas course.

# %% [markdown]
# # **Load Pre-trained Embeddings**
#
# *While you don't have to separate your code into blocks, it might be easier if you separated loading / downloading your data from the main part of your solution. Consider placing all loading of data into the code block below.*

# %%
import gensim.downloader as api
import random

# %%
# twitter ; loads words with 100 dimensions
# change the number to 25/50 to lessen the dimensions and speed up loading
model = api.load("glove-twitter-100")

# wikipedia ; loads words with 100 dimensions
# model_gigaword = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %% [markdown]
# # **Your Implementation**
#
# *Again, you don't have to have everything in one block. Use the notebook according to your preferences with the goal of fulfilling the assessment in mind.*

# %%
# ensures that only the actual words get randomized
words = [word for word in model.index_to_key if word.isalpha()]

# gets the most common 20,000 words in the model
# words = [word for word in model.index_to_key[:20000] if word.isalpha()]

# randomizes the word in words list
random_word = random.choice(words)
